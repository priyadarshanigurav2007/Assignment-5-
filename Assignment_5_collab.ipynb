# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadarshanigurav2007/Assignment-5-/blob/main/Assignment_5_collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Assignment 5

#1.
String = input ("Enter a string :")
print("length of string is :" ,len(String))



#2.
s = input("Enter string:")
print(s[:2] + s[-2:])





#3.
a = input("First: ")
b = input("Second: ")
print(a + b)
# Out:
# Enter a string :“Priya”
# length of string is : 7
# Enter string:“Prachi”
# “Pi”
# First: 7
# Second: 5
# 75
